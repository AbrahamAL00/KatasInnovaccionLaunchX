# %% [markdown]
# # Kata 2

# %% [markdown]
# Crear un entorno virtual

# %%
from IPython import display
display.Image("./k2_1.png")

# %%
from IPython import display
display.Image("./k2_2.png")

# %% [markdown]
# Instalar una biblioteca

# %%
from IPython import display
display.Image("./k2_3.png")

# %% [markdown]
# Desactivar un entorno virtual

# %%
from IPython import display
display.Image("./k2_4.png")
